# %% [markdown]
# <a href="https://colab.research.google.com/github/Daianb/TareasProgramacion/blob/master/TareaMatricz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Matriz: 
 def __init__(self, lista):
    self.a00 = lista[0][0]
    self.a01 = lista[0][1]
    self.a10 = lista[1][0]
    self.a11 = lista[1][1]

 def __str__(self):
  Res = "| "+str(self.a00)+"  "+str(self.a01)+" |\n| "+str(self.a10)+"  "+str(self.a11)+" |"
  return(Res)
 #def __str__(self):
  #Res = "|{:^5} {:^5}|\n|{:^5} {:^5}|".format(self.a00, self.a01, self.a10, self.a11)
  #return(Res)

 def __add__(self,otra):
    a00 = self.a00 + otra.a00
    a01 = self.a01 + otra.a01
    a10 = self.a10 + otra.a10
    a11 = self.a11 + otra.a11
    return(Matriz([[a00,a01],[a10,a11]]))

 def __sub__(self,otra):
    a00 = self.a00 - otra.a00
    a01 = self.a01 - otra.a01
    a10 = self.a10 - otra.a10
    a11 = self.a11 - otra.a11
    return(Matriz([[a00,a01],[a10,a11]]))

 def __mul__(self,otra):
    if type(otra)==type(self):
      return("Aún no se hacer eso princesa, pronto XOXO")
    else:
      a00 = self.a00 * otra
      a01 = self.a01 * otra
      a10 = self.a10 * otra
      a11 = self.a11 * otra
      return(Matriz([[a00,a01],[a10,a11]]))

 def __rmul__(self,otra):
    if type(otra)==type(self):
      return("Aún no se hacer eso princesa, pronto XOXO")
    else:
      a00 = self.a00 * otra
      a01 = self.a01 * otra
      a10 = self.a10 * otra
      a11 = self.a11 * otra
      return(Matriz([[a00,a01],[a10,a11]]))

 def iesima(self, ie):
     if ie == 1:
        return("| "+str(self.a00)+" |\n| "+str(self.a10)+" |" )
     elif ie == 2:
        return ("| "+str(self.a01)+" |\n| "+str(self.a11)+" |" )
     else:
        return("Así no princesa.. ")

print('-'*20,'Matriz A','-'*20)
print("Ingresa el valor de la primera matriz: ")
a00 = int(input("Ingresa el primer valor: "))
a01 = int(input("Ingresa el segundo valor: "))
a10 = int(input("Ingresa el tercer valor: "))
a11 = int(input("Ingresa el cuarto valor: "))
Ma = Matriz([[a00,a11],[a10,a11]])

print('-'*20,'Matriz B','-'*20)
print("Ingresa el valor de la segunda matriz: ")
b00 = int(input("Ingresa el primer valor: "))
b01 = int(input("Ingresa el segundo valor: "))
b10 = int(input("Ingresa el tercer valor: "))
b11 = int(input("Ingresa el cuarto valor: "))
Mb = Matriz([[b00,b11],[b10,b11]])

otra = int(input("\n Ingresa un escalar: "))

AB = int(input("Cuál Matriz deseas ver su i-ésima columna A=1 B=2 :" ))
if AB == 1:
 ie = int(input("Ingresa la i-ésima columna que deseas ver 1 o 2: "))
 columna = Ma.iesima(ie)
elif AB == 2:
  ie = int(input("Ingresa la i-ésima columna que deseas ver 1 o 2: "))
  columna = Mb.iesima(ie)
else: 
  print("Que escojas una ehhh ")

print('-'*20,'Matriz A','-'*20)
print(Ma)

print('-'*20,'Matriz B','-'*20)
print(Mb)

print('-'*18,'Suma de A + B','-'*17)
sumaAB = Ma + Mb 
print(sumaAB)

print('-'*17,'Resta de A - B','-'*17)
restaAB = Ma - Mb
print(restaAB)

print('-'*17,'Resta de B - A','-'*17)
restaBA = Mb - Ma
print(restaBA)

print('-'*18,'Escalar por A','-'*17)
escA = Ma * otra
print(escA)

print('-'*18,'Escalar por B','-'*17)
escB = Mb * otra
print(escB)

print("\nLa columna i-ésima que solicitaste es: ")
print(columna)
# Out:
# -------------------- Matriz A --------------------
# Ingresa el valor de la primera matriz:
# Ingresa el primer valor: 1
# Ingresa el segundo valor: 0
# Ingresa el tercer valor: 3
# Ingresa el cuarto valor: 4
# -------------------- Matriz B --------------------
# Ingresa el valor de la segunda matriz:
# Ingresa el primer valor: 0
# Ingresa el segundo valor: 3
# Ingresa el tercer valor: 4
# Ingresa el cuarto valor: 9
#
#  Ingresa un escalar: 1
# Cuál Matriz deseas ver su i-ésima columna A=1 B=2 :2
# Ingresa la i-ésima columna que deseas ver 1 o 2: 1
# -------------------- Matriz A --------------------
# | 1  4 |
# | 3  4 |
# -------------------- Matriz B --------------------
# | 0  9 |
# | 4  9 |
# ------------------ Suma de A + B -----------------
# | 1  13 |
# | 7  13 |
# ----------------- Resta de A - B -----------------
# | 1  -5 |
# | -1  -5 |
# ----------------- Resta de B - A -----------------
# | -1  5 |
# | 1  5 |
# ------------------ Escalar por A -----------------
# ...
